# %% [markdown]
# <a href="https://colab.research.google.com/github/divya031904/SmartSDLC/blob/main/Copy_of_divyadharshini%20day_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DAY 10

# %% [markdown]
# # ASSESSMENT- BIKE BUYER DATASET

# %%
import pandas as pd

df = pd.read_excel(r"E:\divyadharshini\BIKE BUYER RAW DATA.xlsx")

print(df.head())
print(df.isnull().sum())

df = df.drop_duplicates()

df.to_excel(r"E:\divyadharshini\cleaned_BIKE_BUYER_RAW_DATA.xlsx", index=False)

print("EXCEL DATASET LOADED AND CLEANED SUCCESSFULLY")
# Out:
#       ID Marital Status Gender      Income  Children        Education  \
# 0  12496              M      F  $40,000.00         1  Partial College
# 1  24107              M      M  $30,000.00         3  Partial College
# 2  14177              M      M  $80,000.00         5  Partial College
# 3  24381              S      M  $70,000.00         0        Bachelors
# 4  25597              S      M  $30,000.00         0        Bachelors
#
#        Occupation Home Owner  Cars Commute Distance   Region  Age  \
# 0  Skilled Manual        Yes     0        0-1 Miles   Europe   42
# 1        Clerical        Yes     1        0-1 Miles   Europe   43
# 2    Professional         No     2        2-5 Miles   Europe   60
# 3    Professional        Yes     1       5-10 Miles  Pacific   41
# 4        Clerical         No     0        0-1 Miles   Europe   36
#
#   Purchased Bike
# 0             No
# 1             No
# 2             No
# 3            Yes
# 4            Yes
# ID                  0
# ...
