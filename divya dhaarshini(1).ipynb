# %% [markdown]
# <a href="https://colab.research.google.com/github/divya031904/SmartSDLC/blob/main/divya%20dhaarshini(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[21,90,8,9,10]
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,7,9]
y=[4,8,6,5,3]
plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
y=[4,8,6,5,3]
plt.hist(y)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,7,9]
y=[4,8,6,5,3]
plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([34,56,78,89])
plt.pie(y)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

x = [1,2,3,7,9]
y = [4,8,6,5,3]
plt.title("Abarna Technologies")

plt.boxplot([x,y],patch_artist=True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd


iris = pd.read_excel("C:\\Users\\PG\\Downloads\\retail_sales - Copy.xlsx")


sns.barplot(data=iris)


plt.title("MPH TECHNOLOGIES")


plt.xlabel("Variables")
plt.ylabel("Values")


plt.show()
